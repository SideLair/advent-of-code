# %%
with open('input.txt') as f:
    input = [tuple(line.split()) for line in f]

# %%
input
# Out:
# [('forward', '6'),
#  ('forward', '6'),
#  ('down', '6'),
#  ('down', '5'),
#  ('up', '2'),
#  ('forward', '4'),
#  ('forward', '8'),
#  ('up', '9'),
#  ('forward', '3'),
#  ('down', '1'),
#  ('forward', '2'),
#  ('forward', '3'),
#  ('down', '1'),
#  ('down', '3'),
#  ('down', '3'),
#  ('forward', '9'),
#  ('down', '6'),
#  ('forward', '1'),
#  ('up', '5'),
#  ('down', '1'),
#  ('forward', '8'),
#  ('forward', '7'),
#  ('up', '8'),
#  ('forward', '7'),
#  ('down', '9'),
#  ('forward', '5'),
#  ('forward', '4'),
#  ('forward', '2'),
#  ('down', '3'),
#  ('down', '6'),
#  ('down', '6'),
#  ('down', '5'),
#  ('forward', '5'),
#  ('forward', '4'),
#  ('forward', '8'),
#  ('up', '3'),
#  ('forward', '6'),
#  ('down', '4'),
#  ('up', '2'),
#  ('forward', '8'),
#  ('forward', '6'),
#  ('forward', '1'),
#  ('up', '2'),
#  ('down', '9'),
#  ('down', '9'),
#  ('up', '5'),
#  ('down', '1'),
#  ('up', '1'),
#  ('up', '3'),
#  ('forward', '2'),
#  ('forward', '4'),
#  ('down', '8'),
# ...

# %%
hor = 0
dep = 0
aim = 0

for command in input:
    if command[0] == 'forward':
        hor += int(command[1])
        dep += aim * int(command[1])
    elif command[0] == 'up':
        aim -= int(command[1])
    else:
        aim += int(command[1])

print(f'{hor=} * {dep=} = {hor * dep}')
# Out:
# hor=1988 * dep=874891 = 1739283308
